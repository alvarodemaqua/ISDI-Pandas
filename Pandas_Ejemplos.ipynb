# %% [markdown]
# # Importar Pandas y verificar versión

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %% [markdown]
# # Series
#
# Una Serie es un arreglo unidimensional capaz de almacenar cualquier tipo de datos. Es similar a una columna en una hoja de cálculo o una lista en Python, pero con capacidades adicionales para análisis de datos

# %%
data = [1, 2, 3, 4]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
indices = ['a', 'b', 'c', 'd']
series = pd.Series(data, index=indices)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# # Dataframes
#
# Un DataFrame es una estructura bidimensional, tamaño mutable, y datos potencialmente heterogéneos. Es similar a una tabla en una base de datos, una hoja de cálculo o un diccionario de Series

# %%
data = {'Columna 1': [1, 2, 3], 'Columna 2': ['a', 'b', 'c']}
df = pd.DataFrame(data)
print(df)
# Out:
#    Columna 1 Columna 2
# 0          1         a
# 1          2         b
# 2          3         c

# %% [markdown]
# # Origenes
#
# Pandas soporta la lectura de una variedad de formatos de archivo, lo que facilita comenzar tu análisis

# %%
data = pd.read_csv('https://raw.githubusercontent.com/alvarodemaqua/ISDI-Pandas/main/csv/most-popular.csv', on_bad_lines='skip')

# %%
data
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
excel_data = pd.read_excel('https://github.com/alvarodemaqua/ISDI-Pandas/raw/main/excel/SuperStoreUS-2015.xlsx')

# %%
excel_data
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
data.head()
# Out:
#           category  rank        show_title season_title  \
# 0  Films (English)     1        Red Notice          NaN
# 1  Films (English)     2     Don't Look Up          NaN
# 2  Films (English)     3  The Adam Project          NaN
# 3  Films (English)     4          Bird Box          NaN
# 4  Films (English)     5      The Gray Man          NaN
#
#    hours_viewed_first_91_days  runtime  views_first_91_days
# 0                   454200000   1.9667            230900000
# 1                   408600000   2.3833            171400000
# 2                   281000000   1.7833            157600000
# 3                   325300000   2.0667            157400000
# 4                   299500000   2.1500            139300000

# %%
data.tail()
# Out:
#             category  rank          show_title                  season_title  \
# 35  TV (Non-English)     6               Lupin                 Lupin: Part 2
# 36  TV (Non-English)     7    Who Killed Sara?    Who Killed Sara?: Season 1
# 37  TV (Non-English)     8  All of Us Are Dead  All of Us Are Dead: Season 1
# 38  TV (Non-English)     9          Dear Child    Dear Child: Limited Series
# 39  TV (Non-English)    10               Elite               Elite: Season 3
#
#     hours_viewed_first_91_days  runtime  views_first_91_days
# 35                   258900000   3.7833             68400000
# 36                   392400000   6.7167             58400000
# 37                   679300000  12.2333             55500000
# 38                   245400000   4.8167             50900000
# 39                   334800000   6.7000             50000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   category                    40 non-null     object
#  1   rank                        40 non-null     int64
#  2   show_title                  40 non-null     object
#  3   season_title                19 non-null     object
#  4   hours_viewed_first_91_days  40 non-null     int64
#  5   runtime                     40 non-null     float64
#  6   views_first_91_days         40 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.3+ KB

# %%
data.describe()
# Out:
#             rank  hours_viewed_first_91_days    runtime  views_first_91_days
# count  40.000000                4.000000e+01  40.000000         4.000000e+01
# mean    5.500000                5.194500e+08   4.759585         1.079825e+08
# std     2.908872                4.851032e+08   3.257445         5.356564e+07
# min     1.000000                8.650000e+07   1.533300         4.860000e+07
# 25%     3.000000                2.180500e+08   1.962525         6.105000e+07
# 50%     5.500000                3.300500e+08   3.133300         9.870000e+07
# 75%     8.000000                7.116750e+08   7.000025         1.363250e+08
# max    10.000000                2.205200e+09  13.066700         2.652000e+08

# %%
data.isnull().sum()
# Out:
# category                       0
# rank                           0
# show_title                     0
# season_title                  21
# hours_viewed_first_91_days     0
# runtime                        0
# views_first_91_days            0
# dtype: int64

# %%
data.dropna()
# Out:
#             category  rank          show_title  \
# 20      TV (English)     1           Wednesday
# 21      TV (English)     2     Stranger Things
# 22      TV (English)     3              DAHMER
# 23      TV (English)     4          Bridgerton
# 24      TV (English)     5  The Queen's Gambit
# 25      TV (English)     6     The Night Agent
# 26      TV (English)     7     Stranger Things
# 27      TV (English)     8          Bridgerton
# 28      TV (English)     9         The Witcher
# 30  TV (Non-English)     1          Squid Game
# 31  TV (Non-English)     2         Money Heist
# 32  TV (Non-English)     3               Lupin
# 33  TV (Non-English)     4         Money Heist
# 34  TV (Non-English)     5         Money Heist
# 35  TV (Non-English)     6               Lupin
# 36  TV (Non-English)     7    Who Killed Sara?
# 37  TV (Non-English)     8  All of Us Are Dead
# 38  TV (Non-English)     9          Dear Child
# 39  TV (Non-English)    10               Elite
#
# ...

# %%
data.dropna(how='all')
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
value = {'season_title': 'No aplica'}
data.fillna(value = value)
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %% [markdown]
# # Selección, filtrado y alteración

# %%
columna = data.show_title

# %%
columna
# Out:
# 0                              Red Notice
# 1                           Don't Look Up
# 2                        The Adam Project
# 3                                Bird Box
# 4                            The Gray Man
# 5                        We Can Be Heroes
# 6                              The Mother
# 7       Glass Onion: A Knives Out Mystery
# 8                              Extraction
# 9                            Extraction 2
# 10                                  Troll
# 11                                Nowhere
# 12                           The Platform
# 13                      Through My Window
# 14                                    AKA
# 15                          Blood Red Sky
# 16                    My Name Is Vendetta
# 17                             Black Crab
# 18         All Quiet on the Western Front
# 19                             Below Zero
# 20                              Wednesday
# 21                        Stranger Things
# ...

# %%
columnas = data[['show_title', 'views_first_91_days']]

# %%
columnas
# Out:
#                              show_title  views_first_91_days
# 0                            Red Notice            230900000
# 1                         Don't Look Up            171400000
# 2                      The Adam Project            157600000
# 3                              Bird Box            157400000
# 4                          The Gray Man            139300000
# 5                      We Can Be Heroes            137300000
# 6                            The Mother            136400000
# 7     Glass Onion: A Knives Out Mystery            136300000
# 8                            Extraction            135700000
# 9                          Extraction 2            134900000
# 10                                Troll            103000000
# 11                              Nowhere             83700000
# 12                         The Platform             82800000
# 13                    Through My Window             61100000
# ...

# %%
data.iloc[3] # Selecciona fila 4
# Out:
# category                      Films (English)
# rank                                        4
# show_title                           Bird Box
# season_title                              NaN
# hours_viewed_first_91_days          325300000
# runtime                                2.0667
# views_first_91_days                 157400000
# Name: 3, dtype: object

# %%
rango_filas = data.iloc[1:5]

# %%
rango_filas
# Out:
#           category  rank        show_title season_title  \
# 1  Films (English)     2     Don't Look Up          NaN
# 2  Films (English)     3  The Adam Project          NaN
# 3  Films (English)     4          Bird Box          NaN
# 4  Films (English)     5      The Gray Man          NaN
#
#    hours_viewed_first_91_days  runtime  views_first_91_days
# 1                   408600000   2.3833            171400000
# 2                   281000000   1.7833            157600000
# 3                   325300000   2.0667            157400000
# 4                   299500000   2.1500            139300000

# %%
filtrado = data[data['category'] == 'Films (English)']

# %%
filtrado
# Out:
#           category  rank                         show_title season_title  \
# 0  Films (English)     1                         Red Notice          NaN
# 1  Films (English)     2                      Don't Look Up          NaN
# 2  Films (English)     3                   The Adam Project          NaN
# 3  Films (English)     4                           Bird Box          NaN
# 4  Films (English)     5                       The Gray Man          NaN
# 5  Films (English)     6                   We Can Be Heroes          NaN
# 6  Films (English)     7                         The Mother          NaN
# 7  Films (English)     8  Glass Onion: A Knives Out Mystery          NaN
# 8  Films (English)     9                         Extraction          NaN
# 9  Films (English)    10                       Extraction 2          NaN
#
#    hours_viewed_first_91_days  runtime  views_first_91_days
# 0                   454200000   1.9667            230900000
# ...

# %%
nuevo_filtrado = data[(data['category'] == 'Films (English)') & (data['hours_viewed_first_91_days'] > 300000000)]

# %%
nuevo_filtrado
# Out:
#           category  rank                         show_title season_title  \
# 0  Films (English)     1                         Red Notice          NaN
# 1  Films (English)     2                      Don't Look Up          NaN
# 3  Films (English)     4                           Bird Box          NaN
# 7  Films (English)     8  Glass Onion: A Knives Out Mystery          NaN
#
#    hours_viewed_first_91_days  runtime  views_first_91_days
# 0                   454200000   1.9667            230900000
# 1                   408600000   2.3833            171400000
# 3                   325300000   2.0667            157400000
# 7                   320300000   2.3500            136300000

# %%
copia_data = data

# %%
copia_data['horas_por_vista'] = copia_data['hours_viewed_first_91_days'] / copia_data['views_first_91_days']

# %%
copia_data
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
copia_data['conversion_horas_a_dias'] = copia_data['hours_viewed_first_91_days'] / 24

# %%
copia_data
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
copia_data.drop('horas_por_vista', axis=1)
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
copia_data.drop(copia_data.index[0], inplace=True)

# %%
copia_data
# Out:
#                category  rank                           show_title  \
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# 13  Films (Non-English)     4                    Through My Window
# ...

# %%
agrupacion = copia_data.groupby('category')

# %%
#sumamos runtimes
suma_grupo = agrupacion.sum(numeric_only=True)

# %%
suma_grupo
# Out:
#                      rank  hours_viewed_first_91_days  runtime  \
# category
# Films (English)        54                  2677400000  18.4000
# Films (Non-English)    55                  1232900000  18.8500
# TV (English)           55                  9770500000  82.3334
# TV (Non-English)       55                  6643000000  68.8333
#
#                      views_first_91_days  horas_por_vista  \
# category
# Films (English)               1306300000        18.399731
# Films (Non-English)            663400000        18.849363
# TV (English)                  1185600000        82.326717
# TV (Non-English)               933100000        68.836409
#
#                      conversion_horas_a_dias
# category
# Films (English)                 1.115583e+08
# Films (Non-English)             5.137083e+07
# TV (English)                    4.071042e+08
# TV (Non-English)                2.767917e+08

# %%
media_grupo = agrupacion.mean(numeric_only = True)

# %%
media_grupo
# Out:
#                      rank  hours_viewed_first_91_days   runtime  \
# category
# Films (English)       6.0                2.974889e+08  2.044444
# Films (Non-English)   5.5                1.232900e+08  1.885000
# TV (English)          5.5                9.770500e+08  8.233340
# TV (Non-English)      5.5                6.643000e+08  6.883330
#
#                      views_first_91_days  horas_por_vista  \
# category
# Films (English)             1.451444e+08         2.044415
# Films (Non-English)         6.634000e+07         1.884936
# TV (English)                1.185600e+08         8.232672
# TV (Non-English)            9.331000e+07         6.883641
#
#                      conversion_horas_a_dias
# category
# Films (English)                 1.239537e+07
# Films (Non-English)             5.137083e+06
# TV (English)                    4.071042e+07
# TV (Non-English)                2.767917e+07

# %%
conteo_agrupado = agrupacion.count()

# %%
conteo_agrupado
# Out:
#                      rank  show_title  season_title  \
# category
# Films (English)         9           9             0
# Films (Non-English)    10          10             0
# TV (English)           10          10             9
# TV (Non-English)       10          10            10
#
#                      hours_viewed_first_91_days  runtime  views_first_91_days  \
# category
# Films (English)                               9        9                    9
# Films (Non-English)                          10       10                   10
# TV (English)                                 10       10                   10
# TV (Non-English)                             10       10                   10
#
#                      horas_por_vista  conversion_horas_a_dias
# category
# Films (English)                    9                        9
# Films (Non-English)               10                       10
# TV (English)                      10                       10
# ...

# %%
horas_visualizacion_por_categoria = copia_data.groupby('category')['runtime'].sum()

# %%
horas_visualizacion_por_categoria
# Out:
# category
# Films (English)        18.4000
# Films (Non-English)    18.8500
# TV (English)           82.3334
# TV (Non-English)       68.8333
# Name: runtime, dtype: float64

# %%
grupos_filtrados = copia_data.groupby('category').filter(lambda x: x['runtime'].sum() > 20)

# %%
grupos_filtrados
# Out:
#             category  rank                           show_title  \
# 20      TV (English)     1                            Wednesday
# 21      TV (English)     2                      Stranger Things
# 22      TV (English)     3                               DAHMER
# 23      TV (English)     4                           Bridgerton
# 24      TV (English)     5                   The Queen's Gambit
# 25      TV (English)     6                      The Night Agent
# 26      TV (English)     7                      Stranger Things
# 27      TV (English)     8                           Bridgerton
# 28      TV (English)     9                          The Witcher
# 29      TV (English)    10  Queen Charlotte: A Bridgerton Story
# 30  TV (Non-English)     1                           Squid Game
# 31  TV (Non-English)     2                          Money Heist
# 32  TV (Non-English)     3                                Lupin
# 33  TV (Non-English)     4                          Money Heist
# ...
